# %% [markdown]
# # Importações que são essenciais

# %%
#Carregar informações de senha e login
# %run "dataLogin.ipynb"
import pandas as pd
import matplotlib.pyplot as plt
import climateservaccess as ca
import json
import ipywidgets as widgets
import pyperclip
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import datetime
import numpy as np
import os
import requests
import time
import rasterio
import rasterio.plot

# %% [markdown]
# # Definindo os parametros

# %%
_res = 2 # tamanho da região a ser analizada
user = _usuario
password = _senha
_posMaps = [-8.338618191802494, -36.422912179524886]
_ano_inicial = 2001
_ano_final = 2023
_NomeLocal = "Tancredo Neves, Belo Jardim - PE"
inDir = 'cache_data'  
api = 'https://appeears.earthdatacloud.nasa.gov/api/'  
if not os.path.exists(inDir):
    os.makedirs(inDir)
_localdataName = f"{inDir}/{_posMaps[0]} {_posMaps[1]} {_res}"
if not os.path.exists(_localdataName):
    os.makedirs(_localdataName)

# %% [markdown]
# ## Criando o bloco a ser analizado

# %% [markdown]
# As informações de coordenadas podem ser melhor visualizadas no seguinte site:
#
# https://geojson.io/
#
# Nele foi feito a seguinte demarcação do mapa para ser utilizado:

# %%
link = "https://geojson.io/#map=8/"+str(round(_posMaps[0],3))+"/"+str(round(_posMaps[1],3))
print(link)
# Out:
# https://geojson.io/#map=8/-8.339/-36.423

# %% [markdown]
# Criar o GEOJson com essas coordenadas

# %%
_quadrado = ca.getBox(_posMaps[0], _posMaps[1], _res) 
data_Json = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "coordinates": [
          [
            _quadrado[0],
            _quadrado[1],
            _quadrado[2],
            _quadrado[3],
            _quadrado[0]
          ]
        ],
        "type": "Polygon"
      }
    }
  ]
}
json_string = json.dumps(data_Json, indent=2)
print(json_string)
button = widgets.Button(description="Copiar GeJson")
def on_button_clicked(b):
    pyperclip.copy(json_string)
button.on_click(on_button_clicked)
button
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {},
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -37.422912179524886,
#               -7.338618191802494
#             ],
#             [
#               -35.422912179524886,
#               -7.338618191802494
#             ],
#             [
#               -35.422912179524886,
#               -9.338618191802494
#             ],
#             [
#               -37.422912179524886,
#               -9.338618191802494
#             ],
#             [
#               -37.422912179524886,
#               -7.338618191802494
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       }
#     }
#   ]
# }
# Button(description='Copiar GeJson', style=ButtonStyle())

# %%
quadrado = Polygon(_quadrado)
quadrado_gdf = gpd.GeoSeries(quadrado)
geo_json_data = quadrado_gdf.to_json()
mapa = folium.Map(location=[_posMaps[0],_posMaps[1]], zoom_start=9)
#quadrado_gdf.add_to(mapa)
folium.GeoJson(geo_json_data).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d8dbf188d72c0c435d36a7c9bede1e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d8dbf188d72c0c435d36a7c9bede1e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d8dbf188d72c0c435d36a7c9bede1e8 = L.map(
#                 &quot;map_8d8dbf188d72c0c435d36a7c9bede1e8&quot;,
#                 {
#                     center: [-8.338618191802494, -36.422912179524886],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71b091eaa800ef470176c3a1bfa531ea = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_71b091eaa800ef470176c3a1bfa531ea.addTo(map_8d8dbf188d72c0c435d36a7c9bede1e8);
#
#
#         function geo_json_0586c9edf05a6cdffb3fba93c55e9f32_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0586c9edf05a6cdffb3fba93c55e9f32 = L.geoJson(null, {
#                 onEachFeature: geo_json_0586c9edf05a6cdffb3fba93c55e9f32_onEachFeature,
#
#         });
#
#         function geo_json_0586c9edf05a6cdffb3fba93c55e9f32_add (data) {
#             geo_json_0586c9edf05a6cdffb3fba93c55e9f32
#                 .addData(data);
#         }
#             geo_json_0586c9edf05a6cdffb3fba93c55e9f32_add({&quot;bbox&quot;: [-37.422912179524886, -9.338618191802494, -35.422912179524886, -7.338618191802494], &quot;features&quot;: [{&quot;bbox&quot;: [-37.422912179524886, -9.338618191802494, -35.422912179524886, -7.338618191802494], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-37.422912179524886, -7.338618191802494], [-35.422912179524886, -7.338618191802494], [-35.422912179524886, -9.338618191802494], [-37.422912179524886, -9.338618191802494], [-37.422912179524886, -7.338618191802494]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#                 geo_json_0586c9edf05a6cdffb3fba93c55e9f32.addTo(map_8d8dbf188d72c0c435d36a7c9bede1e8);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Coletar dados de precipitação de todos os anos indo de mes a mes

# %%
def dias_mes(mes, ano):
  data = datetime.date(ano, mes, 1)
  proximo_mes = data.replace(month=data.month % 12 + 1)
  ultimo_dia = proximo_mes - datetime.timedelta(days=1)
  return ultimo_dia.day
def precipitacao_mes(mes, ano):
    ultimodia = dias_mes(mes, ano)
    data_type = 26 #dados de precipitação
    start_date = "{:02d}/01/{}".format(mes, ano) 
    end_date = "{:02d}/{:02d}/{}".format(mes,ultimodia, ano+1)
    operation_type = 'average'
    polygon = _quadrado
    df = ca.getDataFrame(data_type, start_date, end_date, operation_type, polygon)
    data_df = pd.DataFrame(df['data'].to_list())
    valores = data_df["raw_value"].mean()
    return valores
def precipitacao_ano(ano):
    #_localdataName
    arqName = f"{_localdataName}/{ano} precipit data.csv"
    data_type = 26 #dados de precipitação
    start_date = "01/01/{}".format(ano) 
    end_date = "12/31/{}".format(ano)
    operation_type = 'average'
    polygon = _quadrado
    if os.path.exists(arqName):
        print(f"Arquivo do ano de {ano} já baixado, carregando arquivos locais ...")
        df = pd.read_csv(arqName+".raw")
        return df['raw_value']
    else:
        df = ca.getDataFrame(data_type, start_date, end_date, operation_type, polygon)
        df.to_csv(arqName)
        data_df = pd.DataFrame(df['data'].to_list())
        data_df['raw_value'].to_csv(arqName+".raw")
        return data_df['raw_value']
def downloadinfo(file_url, name):
    response = requests.get(file_url, stream=True)
    file_size = int(response.headers.get("content-length", 0))
    progress = tqdm.tqdm(total=file_size, unit="B", unit_scale=True)
    with open(name, "wb") as f:
        for chunk in response.iter_content(chunk_size=1024):
            f.write(chunk)
            progress.update(len(chunk))
    progress.close()
_precipitacao = {}
for i in range(_ano_inicial,_ano_final+1):
    _precipitacao[i] = precipitacao_ano(i)
# Out:
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2001 to 12/31/2001, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2002 to 12/31/2002, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2003 to 12/31/2003, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2004 to 12/31/2004, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2005 to 12/31/2005, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2006 to 12/31/2006, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2007 to 12/31/2007, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2008 to 12/31/2008, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2009 to 12/31/2009, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2010 to 12/31/2010, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2011 to 12/31/2011, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2012 to 12/31/2012, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2013 to 12/31/2013, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2014 to 12/31/2014, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2015 to 12/31/2015, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2016 to 12/31/2016, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2017 to 12/31/2017, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2018 to 12/31/2018, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2019 to 12/31/2019, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2020 to 12/31/2020, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2021 to 12/31/2021, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2022 to 12/31/2022, average
# > Data retrieved successfully.
# REQUEST SUBMITTED: NASA_IMERG_Late [26], 01/01/2023 to 12/31/2023, average
# > Data retrieved successfully.

# %%
_dados = pd.DataFrame()
_dados["Ano"] = []
_dados["Precipitacao"] = []
for i in range(_ano_inicial,_ano_final+1):
    total = _precipitacao[i].sum()
    _dados.loc[len(_dados.index)] = [i, total]
_dados["Ano"] = _dados["Ano"].astype(int)
_dados
# Out:
#      Ano  Precipitacao
# 0   2001    427.785007
# 1   2002    572.865263
# 2   2003    361.102005
# 3   2004    682.899511
# 4   2005    502.663500
# 5   2006    393.385254
# 6   2007    448.735259
# 7   2008    520.711752
# 8   2009    661.577256
# 9   2010    741.753752
# 10  2011    572.229513
# 11  2012    197.380502
# 12  2013    482.116506
# 13  2014    392.661504
# 14  2015    365.040754
# 15  2016    359.216507
# 16  2017    388.774006
# 17  2018    375.783508
# 18  2019    332.699005
# 19  2020    584.169259
# 20  2021    398.566753
# 21  2022    746.132503
# 22  2023    570.556014

# %%
plt.figure(figsize=(10,5))
plt.plot(_dados["Ano"], _dados["Precipitacao"])
plt.xticks(np.arange(_ano_inicial, _ano_final+1, 1), [str(i) for i in range(_ano_inicial, _ano_final+1)])
plt.xlabel('Anos')
plt.ylabel('Precipitação (mm)')
plt.title(f'Media anual de precipitação em {_NomeLocal}')
plt.show()

# %% [markdown]
# # Pegar agora os dados de evapotranspiração

# %%
token_response = requests.post('{}login'.format(api), auth=(user, password)).json()
token = token_response['token']                 
head = {'Authorization': 'Bearer {}'.format(token)}
print(token_response, token)
# Out:
# {'token_type': 'Bearer', 'token': '1uBCC0xHHDg4XQMTM9-bRnQTB2A0nDTdTYqotfs5e07OkVFTk9MmQvewMNVwf6cADv8ioNwC4eXrk9_E2MwaEg', 'expiration': '2024-01-19T15:49:35Z'} 1uBCC0xHHDg4XQMTM9-bRnQTB2A0nDTdTYqotfs5e07OkVFTk9MmQvewMNVwf6cADv8ioNwC4eXrk9_E2MwaEg

# %%
produto_usado = "MOD16A3GF.061"
lst_response = requests.get('{}product/{}'.format(api, produto_usado)).json()
list(lst_response.keys())
# Out:
# ['ET_500m', 'ET_QC_500m', 'LE_500m', 'PET_500m', 'PLE_500m']

# %%
projections = requests.get('{}spatial/proj'.format(api)).json() 
projs = {}                                  # Create an empty dictionary
for p in projections: projs[p['Name']] = p
projs.keys()
# Out:
# dict_keys(['native', 'geographic', 'sinu_modis', 'albers_weld_alaska', 'albers_weld_conus', 'albers_ard_alaska', 'albers_ard_conus', 'albers_ard_hawaii', 'easegrid_2_global', 'easegrid_2_north'])

# %%
prodLayer = []
bandas_usadas = ['ET_500m',  'PET_500m']
for l in lst_response.keys():
    if l in bandas_usadas:
        prodLayer.append({
                "layer": l,
                "product": produto_usado
              })
prodLayer
# Out:
# [{'layer': 'ET_500m', 'product': 'MOD16A3GF.061'},
#  {'layer': 'PET_500m', 'product': 'MOD16A3GF.061'}]

# %%
#Configuraçoes de tarefa
task_type = ['point','area']        # Type of task, area or point
proj = projs['native']['Name']  # Set output projection 
outFormat = ['geotiff', 'netcdf4']  # Set output file format type
recurring = True                   # Specify True for a recurring date range
yearRange = [_ano_inicial, _ano_final]
task_name = _NomeLocal+" "+str(_ano_inicial)
task = {
        'task_type': task_type[1],
        'task_name': task_name,
        'params': {
             'dates': [
             {
                 'startDate': '01-01',
                 'endDate': '12-31',
                 'yearRange': yearRange,
                 'recurring': recurring
             }],
             'layers': prodLayer,
             'output': {
                     'format': {
                             'type': outFormat[0]}, 
                             'projection': proj},
             'geo': data_Json,
        }
    }
task
# Out:
# {'task_type': 'area',
#  'task_name': 'Tancredo Neves, Belo Jardim - PE 2001',
#  'params': {'dates': [{'startDate': '01-01',
#     'endDate': '12-31',
#     'yearRange': [2001, 2023],
#     'recurring': True}],
#   'layers': [{'layer': 'ET_500m', 'product': 'MOD16A3GF.061'},
#    {'layer': 'PET_500m', 'product': 'MOD16A3GF.061'}],
#   'output': {'format': {'type': 'geotiff'}, 'projection': 'native'},
#   'geo': {'type': 'FeatureCollection',
#    'features': [{'type': 'Feature',
#      'properties': {},
#      'geometry': {'coordinates': [[[-37.422912179524886, -7.338618191802494],
#         [-35.422912179524886, -7.338618191802494],
#         [-35.422912179524886, -9.338618191802494],
#         [-37.422912179524886, -9.338618191802494],
#         [-37.422912179524886, -7.338618191802494]]],
#       'type': 'Polygon'}}]}}}

# %%
task_response = ""
_appEEARsDir = _localdataName+"/"+task_name
if not os.path.exists(_appEEARsDir):
    os.makedirs(_appEEARsDir)
    task_response = requests.post('{}task'.format(api), json=task, headers=head).json()
print(task_response)
# Out:
# {'task_id': '21821be6-08d6-41d6-8ba8-a640c7d82bb1', 'status': 'pending'}

# %%
def status(id_tarefa):
    return requests.get('{}task/{}'.format(api, id_tarefa), headers=head).json()['status']
if task_response != "":
    task_id = task_response['task_id']                                               
    status_response = requests.get('{}status/{}'.format(api, task_id), headers=head).json() 
    print(status_response)
    starttime = time.time()
    intervalo = 20.0
    _status = status(task_id)
    while _status != 'done':
        _status = status(task_id)
        time.sleep(intervalo - ((time.time() - starttime) % intervalo))
        print(_status)
    print(_status)
else:
    print("Os dados já haviam sido baixados")
# Out:
# {'task_id': '21821be6-08d6-41d6-8ba8-a640c7d82bb1', 'status': 'queued', 'user_id': 'bistone3000@gmail.com', 'updated': '2024-01-18T22:04:09.611632', 'status_type': 'task'}
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# queued
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# done
# done

# %%
if task_response != "":
    bundle = requests.get('{}bundle/{}'.format(api,task_id), headers=head).json()  # Call API and return bundle contents for the task_id as json
    files = {}                                                       # Create empty dictionary
    for f in bundle['files']: files[f['file_id']] = f['file_name']
    cont = 0
    numero = len(files)
    for f in files:
        if files[f].endswith('.tif'):
            filename = files[f].split('/')[1]
        else:
            filename = files[f] 
        if os.path.exists(_appEEARsDir +"/"+filename):
            cont += 1
        else:
            dl = requests.get('{}bundle/{}/{}'.format(api, task_id, f), headers=head, stream=True, allow_redirects = 'True')
            filepath = os.path.join(_appEEARsDir, filename)                                                      
            with open(filepath, 'wb') as f:                                                                
                for data in dl.iter_content(chunk_size=8192): f.write(data)
            cont += 1
        print(f"Baixando arquivos {cont} / {numero}")
    print('Todos os arquivos da tarefa salvos em: {}'.format(_appEEARsDir))
# Out:
# Baixando arquivos 1 / 72
# Baixando arquivos 2 / 72
# Baixando arquivos 3 / 72
# Baixando arquivos 4 / 72
# Baixando arquivos 5 / 72
# Baixando arquivos 6 / 72
# Baixando arquivos 7 / 72
# Baixando arquivos 8 / 72
# Baixando arquivos 9 / 72
# Baixando arquivos 10 / 72
# Baixando arquivos 11 / 72
# Baixando arquivos 12 / 72
# Baixando arquivos 13 / 72
# Baixando arquivos 14 / 72
# Baixando arquivos 15 / 72
# Baixando arquivos 16 / 72
# Baixando arquivos 17 / 72
# Baixando arquivos 18 / 72
# Baixando arquivos 19 / 72
# Baixando arquivos 20 / 72
# Baixando arquivos 21 / 72
# Baixando arquivos 22 / 72
# Baixando arquivos 23 / 72
# Baixando arquivos 24 / 72
# Baixando arquivos 25 / 72
# Baixando arquivos 26 / 72
# Baixando arquivos 27 / 72
# Baixando arquivos 28 / 72
# Baixando arquivos 29 / 72
# Baixando arquivos 30 / 72
# Baixando arquivos 31 / 72
# Baixando arquivos 32 / 72
# Baixando arquivos 33 / 72
# Baixando arquivos 34 / 72
# Baixando arquivos 35 / 72
# Baixando arquivos 36 / 72
# Baixando arquivos 37 / 72
# Baixando arquivos 38 / 72
# Baixando arquivos 39 / 72
# Baixando arquivos 40 / 72
# Baixando arquivos 41 / 72
# Baixando arquivos 42 / 72
# Baixando arquivos 43 / 72
# Baixando arquivos 44 / 72
# Baixando arquivos 45 / 72
# Baixando arquivos 46 / 72
# Baixando arquivos 47 / 72
# Baixando arquivos 48 / 72
# Baixando arquivos 49 / 72
# Baixando arquivos 50 / 72
# Baixando arquivos 51 / 72
# Baixando arquivos 52 / 72
# Baixando arquivos 53 / 72
# Baixando arquivos 54 / 72
# Baixando arquivos 55 / 72
# Baixando arquivos 56 / 72
# Baixando arquivos 57 / 72
# Baixando arquivos 58 / 72
# Baixando arquivos 59 / 72
# Baixando arquivos 60 / 72
# Baixando arquivos 61 / 72
# Baixando arquivos 62 / 72
# Baixando arquivos 63 / 72
# Baixando arquivos 64 / 72
# Baixando arquivos 65 / 72
# Baixando arquivos 66 / 72
# Baixando arquivos 67 / 72
# Baixando arquivos 68 / 72
# Baixando arquivos 69 / 72
# Baixando arquivos 70 / 72
# Baixando arquivos 71 / 72
# Baixando arquivos 72 / 72
# Todos os arquivos da tarefa salvos em: cache_data/-8.338618191802494 -36.422912179524886 2/Tancredo Neves, Belo Jardim - PE 2001

# %%
# 26          100.074131  10014.831672         2367.90         2564.7  2301.8
# 27          104.215230  10860.814257         2394.20         2600.9  2320.0
# 28          102.937732  10596.176753         2348.60         2550.0  2279.7
# 29          102.353953  10476.331695         2356.30         2557.1  2287.4
# 30          105.461456  11122.118738         2342.50         2554.1  2268.2
# 31           84.859095   7201.065981         2345.10         2506.1  2293.3
# 32           96.229925   9260.198525         2330.60         2516.1  2267.7
# 33          101.159754  10233.295744         2365.60         2562.5  2302.8
# 34          104.946486  11013.764912         2358.30         2567.0  2289.9
# 35           96.905120   9390.602205         2345.10         2543.7  2281.6
# 36          100.679927  10136.447724         2353.90         2555.1  2284.9
# 37          110.109873  12124.184111         2347.40         2570.3  2272.2
# 38          110.952308  12310.414544         2328.00         2553.0  2250.4
# 39          105.420667  11113.516978         2354.50         2575.3  2279.0
# 40          100.909816  10182.790935         2360.20         2572.2  2286.0
# 41           99.486057   9897.475438         2385.50         2588.9  2316.8
# 42           98.684873   9738.704224         2376.90         2577.4  2305.9
# 43           95.261594   9074.771300         2336.90         2525.7  2275.0
#
#     Lower 1.5 IQR  Lower Quartile
# 0           182.5           535.4
# 1           182.5           624.3
# 2           182.5           443.4
# 3           380.1           753.7
# 4           354.6           674.0
# 5           306.0           630.6
# 6           182.5           601.8
# 7           375.9           724.0
# 8           469.6           802.4
# 9           276.1           703.5
# 10          401.0           783.8
# 11          182.1           355.2
# 12          226.4           410.6
# 13          223.5           536.6
# 14          202.3           381.0
# 15          194.1           416.9
# 16          242.8           499.4
# 17          219.5           527.1
# 18          239.3           521.1
# 19          325.2           711.0
# 20          228.6           531.7
# 21          336.5           759.8
# 22         2044.6          2221.1
# 23         2039.1          2213.1
# 24         1982.5          2190.5
# 25         1991.0          2194.8
# 26         2039.7          2236.6
# 27         2049.7          2256.4
# 28         2012.9          2214.3
# 29         2021.6          2222.4
# 30         1989.8          2201.4
# 31         2076.4          2237.6
# 32         2021.4          2206.9
# 33         2037.4          2234.3
# 34         2010.3          2219.1
# 35         2014.1          2212.7
# 36         2018.2          2219.6
# 37         1975.7          2198.7
# 38         1953.0          2178.0
# 39         1986.5          2207.3
# 40         2006.7          2218.8
# 41         2046.3          2249.8
# 42         2042.7          2243.2
# 43         2022.2          2211.0

# %%
mean_1, mean_2 = np.array_split(_dataEvapo["Mean"], 2)
nova_tabela1 = pd.DataFrame({"ET": mean_1})
nova_tabela2 = pd.DataFrame( {"PET": mean_2.to_list()})
_dados["ET"] = nova_tabela1["ET"]
_dados["PET"] = nova_tabela2["PET"]
_dados
# Out:
# /home/gladis/Ambientes/OndasGravitacionais/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
#      Ano  Precipitacao          ET          PET
# 0   2001    427.785007  710.232274  2275.961984
# 1   2002    572.865263  817.202229  2267.760672
# 2   2003    361.102005  635.216301  2257.887618
# 3   2004    682.899511  916.431290  2257.923297
# 4   2005    502.663500  810.808490  2296.819270
# 5   2006    393.385254  774.562784  2322.496370
# 6   2007    448.735259  791.207974  2278.583871
# 7   2008    520.711752  860.817590  2284.985973
# 8   2009    661.577256  918.823369  2268.901603
# 9   2010    741.753752  852.605698  2286.930301
# 10  2011    572.229513  918.678698  2265.817819
# 11  2012    197.380502  545.499182  2298.997287
# 12  2013    482.116506  647.166732  2284.954057
# 13  2014    392.661504  749.492332  2276.166408
# 14  2015    365.040754  575.677515  2285.055767
# 15  2016    359.216507  616.604515  2270.433812
# 16  2017    388.774006  688.989641  2251.055576
# 17  2018    375.783508  721.975613  2279.805260
# 18  2019    332.699005  716.955812  2287.528054
# 19  2020    584.169259  876.743723  2315.156111
# 20  2021    398.566753  722.978823  2309.688727
# 21  2022    746.132503  909.972777  2271.894900
# 22  2023    570.556014         NaN          NaN

# %%
plt.figure(figsize=(10,5))
plt.plot(_dados["Ano"], _dados["Precipitacao"])
plt.plot(_dados["Ano"], _dados["ET"])
plt.xticks(np.arange(_ano_inicial, _ano_final+1, 1), [str(i) for i in range(_ano_inicial, _ano_final+1)])
plt.xlabel('Anos')
plt.ylabel('(mm)')
plt.title(f'Media anual de precipitação/evaporação em {_NomeLocal}')
plt.show()

# %%
_dados['Indice de Aridez UNEP'] = _dados["Precipitacao"] / _dados["PET"]
_dados['Aridez'] = _dados["Precipitacao"] / _dados["ET"]
_dados
# Out:
#      Ano  Precipitacao          ET          PET  Indice de Arides UNEP  \
# 0   2001    427.785007  710.232274  2275.961984               0.187958
# 1   2002    572.865263  817.202229  2267.760672               0.252613
# 2   2003    361.102005  635.216301  2257.887618               0.159929
# 3   2004    682.899511  916.431290  2257.923297               0.302446
# 4   2005    502.663500  810.808490  2296.819270               0.218852
# 5   2006    393.385254  774.562784  2322.496370               0.169380
# 6   2007    448.735259  791.207974  2278.583871               0.196936
# 7   2008    520.711752  860.817590  2284.985973               0.227884
# 8   2009    661.577256  918.823369  2268.901603               0.291585
# 9   2010    741.753752  852.605698  2286.930301               0.324345
# 10  2011    572.229513  918.678698  2265.817819               0.252549
# 11  2012    197.380502  545.499182  2298.997287               0.085855
# 12  2013    482.116506  647.166732  2284.954057               0.210996
# 13  2014    392.661504  749.492332  2276.166408               0.172510
# 14  2015    365.040754  575.677515  2285.055767               0.159751
# 15  2016    359.216507  616.604515  2270.433812               0.158215
# 16  2017    388.774006  688.989641  2251.055576               0.172707
# 17  2018    375.783508  721.975613  2279.805260               0.164831
# 18  2019    332.699005  716.955812  2287.528054               0.145440
# 19  2020    584.169259  876.743723  2315.156111               0.252324
# 20  2021    398.566753  722.978823  2309.688727               0.172563
# 21  2022    746.132503  909.972777  2271.894900               0.328419
# 22  2023    570.556014         NaN          NaN                    NaN
#
#       Arides
# 0   0.602317
# 1   0.701008
# 2   0.568471
# 3   0.745173
# 4   0.619953
# 5   0.507880
# 6   0.567152
# 7   0.604904
# 8   0.720027
# 9   0.869985
# 10  0.622883
# 11  0.361835
# 12  0.744965
# 13  0.523903
# 14  0.634106
# 15  0.582572
# 16  0.564267
# 17  0.520493
# 18  0.464044
# 19  0.666294
# 20  0.551284
# 21  0.819950
# 22       NaN

# %%
a, b = np.polyfit(_dados["Ano"], _dados["Indice de Aridez UNEP"], 1)
plt.figure(figsize=(10,5))
plt.plot(_dados["Ano"], _dados["Indice de Aridez UNEP"])
plt.plot(_dados["Ano"], a * _dados["Ano"] + b, 'r-')
plt.xticks(np.arange(_ano_inicial, _ano_final+1, 1), [str(i) for i in range(_ano_inicial, _ano_final+1)])
plt.xlabel('Anos')
plt.ylabel('IA')
plt.title(f'Media anual do indice de arides em {_NomeLocal}')
plt.show()

# %% [markdown]
# # calculando resultados

# %%
def categoria_climatica(indice):
    if indice >= 0.65:
        return 'Úmida'
    elif indice >= 0.5:
        return 'Subúmida'
    elif indice >= 0.2:
        return 'Semiárida'
    elif indice >= 0.05:
        return 'Árida'
    else:
        return 'Hiperárida'
def risco_desertificacao(ai):
  if ai < 0.05:
    return "Acima de Muito Alto (MMA)"
  elif 0.05 <= ai <= 0.20:
    return "Muito Alto (MA)"
  elif 0.21 <= ai <= 0.50:
    return "Alto (A)"
  elif 0.51 <= ai <= 0.65:
    return "Moderado (M)"
  else:
    return "Baixo (B)"
_IndiceAridez = _dados['Indice de Aridez UNEP'].mean()
_Aridez = _dados['Indice de Aridez UNEP'].mean()
_AriderN = (a * _dados["Ano"] + b).mean()
aridez = _dados.loc[_dados['Ano'] == _ano_final, 'Indice de Aridez UNEP'].values[0]
print(f"Essa região está classificada atualmente como sendo uma região {arides:.2f}, o que lhe classifica como uma região {categoria_climatica(aridez)}")
print(f"Entre os anos de {_ano_inicial } e {_ano_final}, a região teve um indice medio de {_AriderN:.2f}, o que lhe classifica como uma região {categoria_climatica(_AriderN)}")
print(f"A chance de desertificação da região está classificada como {risco_desertificacao(_AriderN)}")
if a < 0:
    print("Foi observado um processo de diminuição do total de chuva em relação ao total de evaporação")
# Out:
# Essa região está classificada atualmente como sendo uma região nan, o que lhe classifica como uma região Hiperárida
# Entre os anos de 2001 e 2023, a região teve um indice medio de nan, o que lhe classifica como uma região Hiperárida
# A chance de desertificação da região está classificada como Baixo (B)

# %%
_dados["Aridez2"] = _dados["ET"] / _dados["PET"]
_Aridez2 = _dados['Aridez2'].mean()
print(f"Comparando os 2 indices para verificar equivalencia {_Aridez:.2f} ~= {_Aridez2:.2f}")
# Out:
# Comparando os 2 indices para verificar equivalencia 0.21 ~= 0.33

# %%
def mostraGraficoDoAno(ano):
    for f in files:
        if files[f].endswith('.tif'):
            nome = files[f].split('/')[1]
        else:
            nome = files[f]
        if "_ET_5" in nome and f"doy{ano}" in nome:
            et_tif = nome
        if "_PET_5" in nome and f"doy{ano}" in nome:
            pet_tif = nome
    et_tif = _appEEARsDir+"/"+et_tif
    pet_tif = _appEEARsDir+"/"+pet_tif
    with rasterio.open(et_tif) as et:
      et_data = et.read(1) 
    with rasterio.open(pet_tif) as pet:
      pet_data = pet.read(1) 
    arid_data = et_data / pet_data
    plt.imshow(arid_data, cmap='gist_yarg', vmin=0, vmax=1)
    plt.show()
mostraGraficoDoAno(_ano_final-1)
